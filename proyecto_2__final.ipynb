# %% [markdown]
# <a href="https://colab.research.google.com/github/ValenNoble/proyecto_2/blob/main/proyecto_2__final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ValenNoble/proyecto_2.git
# Out:
# fatal: destination path 'proyecto_2' already exists and is not an empty directory.

# %% [markdown]
# ##PREGUNTA 1

# %%
import pandas as pd
import numpy as np

# %%
ruta = "/content/proyecto_2/assets/Energy Indicators.xls"
energy = pd.read_excel(ruta, skiprows = 17, skipfooter = 38)
# Elimina primera dos columnas
energy = energy.iloc[:,2:]

# %%
# Renombrar las columnas
energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']

# %%
energy['Energy Supply'] = energy['Energy Supply'].apply(lambda x: x*1000000 if x != '...'else np.nan)
energy.head()
# Out:
#           Country  Energy Supply Energy Supply per Capita  % Renewable
# 0     Afghanistan   3.210000e+08                       10    78.669280
# 1         Albania   1.020000e+08                       35   100.000000
# 2         Algeria   1.959000e+09                       51     0.551010
# 3  American Samoa            NaN                      ...     0.641026
# 4         Andorra   9.000000e+06                      121    88.695650

# %%
energy['Energy Supply per Capita'] = energy['Energy Supply per Capita'].apply(lambda x: x if x != "..."else np.nan)
energy.head()
# Out:
#           Country  Energy Supply  Energy Supply per Capita  % Renewable
# 0     Afghanistan   3.210000e+08                      10.0    78.669280
# 1         Albania   1.020000e+08                      35.0   100.000000
# 2         Algeria   1.959000e+09                      51.0     0.551010
# 3  American Samoa            NaN                       NaN     0.641026
# 4         Andorra   9.000000e+06                     121.0    88.695650

# %%
# Elimina parentesis
energy['Country'] = energy['Country'].str.replace(r"\s*\(.*\)", "", regex = True)
energy['Country'] = energy['Country'].str.replace(r"\d+$", "", regex = True)
energy["Country"] = energy["Country"].str.strip()
energy.head()
# Out:
#           Country  Energy Supply  Energy Supply per Capita  % Renewable
# 0     Afghanistan   3.210000e+08                      10.0    78.669280
# 1         Albania   1.020000e+08                      35.0   100.000000
# 2         Algeria   1.959000e+09                      51.0     0.551010
# 3  American Samoa            NaN                       NaN     0.641026
# 4         Andorra   9.000000e+06                     121.0    88.695650

# %%
energy["Country"].replace({
    "Republic of Korea": "South Korea",
    "United States of America20": "United States",
    "United Kingdom of Great Britain and Northern Ireland19": "United Kingdom",
    "China, Hong Kong Special Administrative Region3": "Hong Kong",
    "China2":"China",
    "Japan10":"Japan",
    "France6": "France",
    "Italy9": "Italy",
    "Spain16": "Spain",
    "Autralia1": "Australia"
})
# Out:
# 0                    Afghanistan
# 1                        Albania
# 2                        Algeria
# 3                 American Samoa
# 4                        Andorra
#                  ...
# 222                     Viet Nam
# 223    Wallis and Futuna Islands
# 224                        Yemen
# 225                       Zambia
# 226                     Zimbabwe
# Name: Country, Length: 227, dtype: object

# %%
ruta_2 = "/content/proyecto_2/assets/world_bank.csv"

# Cargar datos del PBI a un DataFrame
gdp = pd.read_csv(ruta_2, skiprows=4)

# %%
gdp["Country Name"].replace({
    "Korea, Rep.": "South Korea",
    "Iran, Islamic Rep.": "Iran",
    "Hong Kong SAR, China": "Hong Kong"
},inplace = True)

gdp.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1      Andorra          AND  GDP at market prices (constant 2010 US$)
# 2  Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3       Angola          AGO  GDP at market prices (constant 2010 US$)
# 4      Albania          ALB  GDP at market prices (constant 2010 US$)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...          2006  \
# 0  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 1  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.018196e+09
# 2  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.030523e+10
# 3  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.581103e+10
# 4  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.771760e+09
#
#            2007          2008          2009          2010          2011  \
# ...

# %%
ruta_3 = "/content/proyecto_2/assets/scimagojr-3.xlsx"
scimago = pd.read_excel(ruta_3)
scimago = scimago[scimago["Rank"] <= 15]

# %%
# Ccombinar archivos
def carga_datos():
  combinado = pd.merge(scimago, energy, how = "inner", left_on = "Country", right_on = "Country")
  combinado = pd.merge(combinado, gdp, how = "inner", left_on = "Country", right_on = "Country Name")
  columnas_requeridas = ["Country", "Rank", "Documents", "Citable documents", "Citations", "Self-citations", "Citations per document", "H index", "Energy Supply", "Energy Supply per Capita", "% Renewable", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015"]
  combinado = combinado[columnas_requeridas]
  combinado.set_index('Country', inplace = True)
  return combinado
carga_datos()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# Japan                  3      30504              30287     223024
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# Australia             14       8831               8725      90765
# Brazil                15       8668               8596      60702
#
#                     Self-citations  Citations per document  H index  \
# Country
# ...

# %% [markdown]
# ##PREGUNTA 2

# %%
def outer():
  outer1 = pd.merge(scimago, energy, how="outer", left_on="Country", right_on="Country")
  outer1 = pd.merge(outer1, gdp, how="outer", left_on="Country", right_on="Country Name")
  cantidad = len(outer1)
  cantidad_combinado = len(carga_datos())
  resultado = cantidad - cantidad_combinado
  return resultado
outer()
# Out:
# 297

# %% [markdown]
# ##PREGUNTA 3

# %%
def promedio_pbi():
  gdp_columnas = ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
  gdp_datos = gdp[gdp_columnas]
  avg = gdp_datos.mean(axis = 1)
  avg1 = gdp[["Country Name"]].copy()
  avg1 ["Average GDP"] = avg
  avg1 = avg1.sort_values(by = "Average GDP",ascending = False)
  top15 = avg1.head(15)
  avgGDP = top15.set_index("Country Name")["Average GDP"]
  return avgGDP
promedio_pbi()
# Out:
# Country Name
# World                        6.713548e+13
# High income                  4.586468e+13
# OECD members                 4.514723e+13
# Post-demographic dividend    4.292131e+13
# IDA & IBRD total             2.202600e+13
# Europe & Central Asia        2.117122e+13
# Low & middle income          2.081219e+13
# Middle income                2.051324e+13
# IBRD only                    2.039738e+13
# European Union               1.717367e+13
# East Asia & Pacific          1.714490e+13
# North America                1.703064e+13
# Upper middle income          1.576611e+13
# United States                1.536434e+13
# Late-demographic dividend    1.389504e+13
# Name: Average GDP, dtype: float64

# %% [markdown]
# ##PREGUNTA 4

# %%
def GDP_cambios():
  country_6 = promedio_pbi().index[5]
  GDP2006 = gdp[gdp["Country Name"] == country_6]["2006"].values[0]
  GDP2015 = gdp[gdp["Country Name"] == country_6]["2015"].values[0]
  GDP_cambio= GDP2015 - GDP2006
  return GDP_cambio
GDP_cambios()
# Out:
# 1787625194095.8008

# %% [markdown]
# ##PREGUNTA 5

# %%
def energy_pC():
  avg= carga_datos()["Energy Supply per Capita"].mean()
  return avg
energy_pC()
# Out:
# 144.41666666666666

# %% [markdown]
# ##PREGUNTA 6

# %%
def porcentaje():
  max_renewable_country = carga_datos()['% Renewable'].idxmax()
  max_renewable_percentage = carga_datos().loc[max_renewable_country, '% Renewable']
  return (max_renewable_country, max_renewable_percentage)
porcentaje()
# Out:
# ('Brazil', 69.64803)

# %% [markdown]
# ##PREGUNTA 7

# %%
def relacion_columna():
  datos = carga_datos()
  datos["Citations Ratio"] = datos["Self-citations"]/datos["Citations"]
  maxid = datos["Citations Ratio"].idxmax()
  max = datos.loc[maxid, "Citations Ratio"]
  return (maxid, max)
relacion_columna()
# Out:
# ('China', 0.6893126179389422)

# %% [markdown]
# ##PREGUNTA 8

# %%
def poblacion():
  poblacion1 = carga_datos()
  poblacion1["Population"] = poblacion1["Energy Supply"] / poblacion1["Energy Supply per Capita"]
  poblacion1 = poblacion1.sort_values(by="Population", ascending = False)
  tercer_pais = poblacion1.iloc[2].name
  return tercer_pais
poblacion()

# %% [markdown]
# ##PREGUNTA 9

# %%
def citable_document():
  document = carga_datos()
  document["Citable document per Capita"] = document["Citable documents"] / document["Energy Supply per Capita"]
  correlacion= document["Citable documents"].corr(document["Energy Supply per Capita"])
  return correlacion
citable_document()
# Out:
# -0.1631406241128891

# %% [markdown]
# ##PREGUNTA 10

# %%
def high_renewable():
    datos = carga_datos()
    top15 = datos.head(15)
    median_renewable = top15['% Renewable'].median()
    datos['HighRenew'] = (datos['% Renewable'] >= median_renewable).astype(int)
    high_renew_series = datos.sort_values(by=['HighRenew', 'Rank'], ascending=[False, True])
    return high_renew_series
high_renewable()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Brazil                15       8668               8596      60702
# Japan                  3      30504              30287     223024
# Russian Federation     5      18534              18301      34266
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# Iran                  13       8896               8819      57470
# Australia             14       8831               8725      90765
#
#                     Self-citations  Citations per document  H index  \
# Country
# ...

# %% [markdown]
# ##PREGUNTA 11

# %%
combinado = carga_datos()

# Definir el diccionario de continentes
continent_dict = {'China':'Asia',
                   'United States':'North America',
                   'Japan':'Asia',
                   'United Kingdom':'Europe',
                   'Russian Federation':'Europe',
                   'Canada':'North America',
                   'Germany':'Europe',
                   'India':'Asia',
                   'France':'Europe',
                   'South Korea':'Asia',
                   'Italy':'Europe',
                   'Spain':'Europe',
                   'Iran':'Asia',
                   'Australia':'Australia',
                   'Brazil':'South America'}

# Agregar la columna 'Continent' al DataFrame combinado
combinado['Continent'] = combinado.index.map(continent_dict)

# Agrupar por continente y calcular estadísticas
continent_stats = combinado.groupby('Continent')['Population'].agg(['count', 'sum', 'mean', 'std'])

# Renombrar las columnas
continent_stats.columns = ['size', 'sum', 'mean', 'std']

# Restablecer el índice para tener 'Continent' como una columna
continent_stats.reset_index(inplace=True)

# Mostrar el resultado
print(continent_stats)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-151-14cf78e5c79b> in <cell line: 24>()
#      22
#      23 # Agrupar por continente y calcular estadísticas
# ---> 24 continent_stats = combinado.groupby('Continent')['Population'].agg(['count', 'sum', 'mean', 'std'])
#      25
#      26 # Renombrar las columnas
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1414                 stacklevel=find_stack_level(),
#    1415             )
# -> 1416         return super().__getitem__(key)
#    1417
#    1418     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     246         else:
#     247             if key not in self.obj:
# --> 248                 raise KeyError(f"Column not found: {key}")
# ...
